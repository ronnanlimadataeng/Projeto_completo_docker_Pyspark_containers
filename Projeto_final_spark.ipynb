# %% [markdown]
#    ### Projeto de conclusão de curso "Projeto Final de Spark"
#
#    ### Utilizando dados da "Campanha Nacional de Vacinação contra Covid-19"
#
#
#     1.Enviar os dados para o hdfs
#
#     2.Otimizar todos os dados do hdfs para uma tabela Hive particionada por município.
#
#     3.Criar as 3 vizualizações pelo Spark com os dados enviados para o HDFS:
#
#     4.Salvar a primeira visualização como tabela Hive
#
#     5.Salvar a segunda visualização com formato parquet e compressão snappy
#
#     6.Salvar a terceira visualização em um tópico no Kafka
#
#     7.Criar a visualização pelo Spark com os dados enviados para o HDFS:
#
#     8.Salvar a visualização do exercício 6 em um tópico no Elastic
#
#     9.Criar um dashboard no Elastic para visualização dos novos dados enviados

# %%
# Pre-Requisitos
#a) Fazer donwload do arquivo dentro do cluster - curl -O https://mobileapps.saude.gov.br/esus-vepi/files/unAFkcaNDeXajurGB7LChj8SgQYS2ptm/04bd3419b22b9cc5c6efac2c6528100d_HIST_PAINEL_COVIDBR_06jul2021.rar
#b) extrair arquivo - unrar x 04bd3419b22b9cc5c6efac2c6528100d_HIST_PAINEL_COVIDBR_06jul2021.rar

# %%
# type para inserir dados do separador, schema, header
# functions para utilizar a conversão de tiemstamp para date

from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
# 1.Enviar os dados para o HDFS

# !hdfs dfs -mkdir /user/ronnan/data/data_covid
# !hdfs dfs -put input/data_covid/*csv /user/ronnan/data/data_covid
# Out:
# mkdir: `/user/ronnan/data/data_covid': File exists
# put: `input/data_covid/*csv': No such file or directory

# %%
# verificando se os dados já estão no HDFS

# !hdfs dfs -ls /user/ronnan/data/data_covid
# Out:
# Found 4 items
# -rw-r--r--   3 root supergroup   62492959 2022-04-19 02:29 /user/ronnan/data/data_covid/HIST_PAINEL_COVIDBR_2020_Parte1_06jul2021.csv
# -rw-r--r--   3 root supergroup   76520681 2022-04-19 02:29 /user/ronnan/data/data_covid/HIST_PAINEL_COVIDBR_2020_Parte2_06jul2021.csv
# -rw-r--r--   3 root supergroup   91120916 2022-04-19 02:29 /user/ronnan/data/data_covid/HIST_PAINEL_COVIDBR_2021_Parte1_06jul2021.csv
# -rw-r--r--   3 root supergroup    3046774 2022-04-19 02:29 /user/ronnan/data/data_covid/HIST_PAINEL_COVIDBR_2021_Parte2_06jul2021.csv

# %%
# criando data_frame data_covid para tratamento dos dados, realizando leitura em csv

data_covid = spark.read.csv("/user/ronnan/data/data_covid/*.csv"
                            ,sep = ";",inferSchema=True, header=True,ignoreLeadingWhiteSpace=True)

# %%
# verificando se o esquema foi atribuido

print(data_covid.printSchema())
# Out:
# root
#  |-- regiao: string (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- municipio: string (nullable = true)
#  |-- coduf: integer (nullable = true)
#  |-- codmun: integer (nullable = true)
#  |-- codRegiaoSaude: integer (nullable = true)
#  |-- nomeRegiaoSaude: string (nullable = true)
#  |-- data: timestamp (nullable = true)
#  |-- semanaEpi: integer (nullable = true)
#  |-- populacaoTCU2019: integer (nullable = true)
#  |-- casosAcumulado: decimal(10,0) (nullable = true)
#  |-- casosNovos: integer (nullable = true)
#  |-- obitosAcumulado: integer (nullable = true)
#  |-- obitosNovos: integer (nullable = true)
#  |-- Recuperadosnovos: integer (nullable = true)
#  |-- emAcompanhamentoNovos: integer (nullable = true)
#  |-- interior/metropolitana: integer (nullable = true)
#
# None

# %%
# criando variavel apenas com as colunas que serão utilizadas nas visualizações

dados_filtrados = data_covid.select("data","casosAcumulado","casosNovos","municipio","obitosNovos","Recuperadosnovos","obitosAcumulado","emAcompanhamentoNovos")

# %%
# criando variavel para ajustar o campo para novo formato de data

dados_data_formatada = dados_filtrados.withColumn("data",to_timestamp(col("data"))).withColumn("data",to_date(col("data")))

# %%
# Criando variavel com todos os dados nulls transformados em "0"

dados_filtrados_limpos = dados_data_formatada.na.fill({'municipio': '0', 'Recuperadosnovos':0, 'emAcompanhamentoNovos':0 })

# %%
# 2.Otimizar todos os dados do hdfs para uma tabela Hive particionada por município.

dados_filtrados_limpos.write.saveAsTable("dados_covid", partitionBy="municipio", mode="OverWrite")

# %%
# exibindo a tabela para verificar se dados estão transformados

spark.read.table("dados_covid").show(20)
# Out:
# +----------+--------------+----------+-----------+----------------+---------------+---------------------+---------+
# |      data|casosAcumulado|casosNovos|obitosNovos|Recuperadosnovos|obitosAcumulado|emAcompanhamentoNovos|municipio|
# +----------+--------------+----------+-----------+----------------+---------------+---------------------+---------+
# |2021-01-01|       7700578|     24605|        462|         6756284|         195411|               748883|        0|
# |2021-01-02|       7716405|     15827|        314|         6769420|         195725|               751260|        0|
# |2021-01-03|       7733746|     17341|        293|         6813008|         196018|               724720|        0|
# |2021-01-04|       7753752|     20006|        543|         6875230|         196561|               681961|        0|
# |2021-01-05|       7810400|     56648|       1171|         6963407|         197732|               649261|        0|
# |2021-01-06|       7873830|     63430|       1242|         7036530|         198974|               638326|        0|
# |2021-01-07|       7961673|     87843|       1524|         7096931|         200498|               664244|        0|
# |2021-01-08|       8013708|     52035|        962|         7114474|         201460|               697774|        0|
# |2021-01-09|       8075998|     62290|       1171|         7144011|         202631|               729356|        0|
# |2021-01-10|       8105790|     29792|        469|         7167651|         203100|               735039|        0|
# |2021-01-11|       8131612|     25822|        480|         7207483|         203580|               720549|        0|
# |2021-01-12|       8195637|     64025|       1110|         7273707|         204690|               717240|        0|
# |2021-01-13|       8256536|     60899|       1274|         7277195|         205964|               713752|        0|
# |2021-01-13|       8256536|         0|          0|         7316944|         205964|               733628|        0|
# |2021-01-14|       8324294|     67758|       1131|         7339703|         207095|               777496|        0|
# |2021-01-15|       8393492|     69198|       1151|         7361379|         208246|               823867|        0|
# |2021-01-16|       8455059|     61567|       1050|         7388784|         209296|               856979|        0|
# |2021-01-17|       8488099|     33040|        551|         7411654|         209847|               866598|        0|
# |2021-01-18|       8511770|     23671|        452|         7452047|         210299|               849424|        0|
# |2021-01-19|       8573864|     62094|       1192|         7518846|         211491|               843527|        0|
# +----------+--------------+----------+-----------+----------------+---------------+---------------------+---------+
# only showing top 20 rows

# %%
# verificando se a tabela foi salva dentro do Hive e os diretorios foram criados por municipio

# !hdfs dfs -ls /user/hive/warehouse/dados_covid
# Out:
# Found 5299 items
# -rw-r--r--   2 root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vinhedo
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Viradouro
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Virgem da Lapa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Virginópolis
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Virgolândia
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Virgínia
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Virmond
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Visconde do Rio Branco
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Viseu
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vista Alegre
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vista Alegre do Alto
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vista Alegre do Prata
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vista Gaúcha
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vista Serrana
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitor Meireles
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitorino
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitorino Freire
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória Brasil
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória da Conquista
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória das Missões
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória de Santo Antão
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória do Jari
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória do Mearim
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Vitória do Xingu
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Viçosa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Viçosa do Ceará
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Volta Grande
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Volta Redonda
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Votorantim
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Votuporanga
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea Alegre
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea Branca
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea Grande
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea Nova
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea Paulista
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea da Palma
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea da Roça
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Várzea do Poço
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wagner
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wall Ferraz
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wanderley
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wanderlândia
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wenceslau Braz
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Wenceslau Guimarães
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Westfália
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Witmarsum
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xambioá
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xambrê
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xangri-lá
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xanxerê
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xapuri
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xavantina
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xaxim
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xexéu
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xinguara
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Xique-Xique
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Zabelê
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Zacarias
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Zortéa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Zé Doca
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Azul do Norte
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Boa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Branca
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Clara
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Comprida
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Doce
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Doce do Maranhão
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Doce do Norte
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Fria
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Fria de Goiás
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Limpa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Nova
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Preta
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Água Santa
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Belas
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Formosas
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Frias
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Lindas de Goiás
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Mornas
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas Vermelhas
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas da Prata
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas de Chapecó
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas de Lindóia
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas de Santa Bárbara
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águas de São Pedro
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Águia Branca
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Álvares Florence
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Álvares Machado
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Álvaro de Carvalho
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Áurea
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Ângulo
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Érico Cardoso
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Óbidos
# drwxr-xr-x   - root supergroup          0 2022-04-21 01:12 /user/hive/warehouse/dados_covid/municipio=Óleo

# %%
# 3.Criar as 3 vizualizações pelo Spark com os dados enviados para o HDFS

#3.1ª visualizacao

dados_casos_recuperados = dados_filtrados_limpos.select(max('Recuperadosnovos').alias("Casos_Recuperados"), \
                                                max('emAcompanhamentoNovos').alias("Em_Acompanhamento"))

dados_casos_recuperados_visualização = dados_casos_recuperados.show()
# Out:
# +-----------------+-----------------+
# |Casos_Recuperados|Em_Acompanhamento|
# +-----------------+-----------------+
# |         17262646|          1317658|
# +-----------------+-----------------+

# %%
#3.2ª visualizacao

dados_casos_confirmados = dados_filtrados_limpos.select(max('casosAcumulado').alias("Casos_Confirmados"), \
                                               max('casosNovos').alias("Casos_Novos"))

dados_casos_confirmados_visualização = dados_casos_confirmados.show()
# Out:
# +-----------------+-----------+
# |Casos_Confirmados|Casos_Novos|
# +-----------------+-----------+
# |         18855015|     115228|
# +-----------------+-----------+

# %%
#taxa mortalidade = n de obitos x 1000 / n abitantes
# 526892 * 1000 / 210147125 = 250725

total_populacao = data_covid.select(max('populacaoTCU2019'))

total_populacao_visualização = total_populacao.show()
# Out:
# +---------------------+
# |max(populacaoTCU2019)|
# +---------------------+
# |            210147125|
# +---------------------+

# %%
# 3.3ª visualizacao

dados_obitos_confirmados = dados_filtrados_limpos.select(max('obitosAcumulado').alias("Obitos_Confirmados"), \
                                                max('obitosNovos').alias("Obitos_Novos"))
dados_obitos_confirmados_taxa = dados_obitos_confirmados.withColumn("Taxa_Mortalidade", lit(526892*1000/210147125))

dados_obitos_confirmados_taxa_visualização = dados_obitos_confirmados_taxa.show()
# Out:
# +------------------+------------+------------------+
# |Obitos_Confirmados|Obitos_Novos|  Taxa_Mortalidade|
# +------------------+------------+------------------+
# |            526892|        4249|2.5072529543290205|
# +------------------+------------+------------------+

# %%
# 4.Salvar a primeira visualização como tabela Hive

dados_casos_recuperados.write.saveAsTable("casos_recuperados")

# %%
# visualizar a tabela casos_recuperados salva no Hive

spark.read.table('casos_recuperados').show()
# Out:
# +-----------------+-----------------+
# |Casos_Recuperados|Em_Acompanhamento|
# +-----------------+-----------------+
# |         17262646|          1317658|
# +-----------------+-----------------+

# %%
# 5.Salvar a segunda visualização com formato parquet e compressão snappy

dados_casos_confirmados.write.saveAsTable("casos_confirmados_snappy", format="parquet", compression="snappy")

# %%
# visualizar a tabela salva em parquet e compressa em snappy

spark.sql('''describe formatted casos_confirmados_snappy''').show()
# Out:
# +--------------------+--------------------+-------+
# |            col_name|           data_type|comment|
# +--------------------+--------------------+-------+
# |   Casos_Confirmados|       decimal(10,0)|   null|
# |         Casos_Novos|                 int|   null|
# |                    |                    |       |
# |# Detailed Table ...|                    |       |
# |            Database|             default|       |
# |               Table|casos_confirmados...|       |
# |               Owner|                root|       |
# |        Created Time|Thu Apr 21 01:31:...|       |
# |         Last Access|Thu Jan 01 00:00:...|       |
# |          Created By|         Spark 2.4.1|       |
# |                Type|             MANAGED|       |
# |            Provider|             parquet|       |
# |    Table Properties|[transient_lastDd...|       |
# |          Statistics|           713 bytes|       |
# |            Location|hdfs://namenode:8...|       |
# |       Serde Library|org.apache.hadoop...|       |
# |         InputFormat|org.apache.hadoop...|       |
# |        OutputFormat|org.apache.hadoop...|       |
# |  Storage Properties|[serialization.fo...|       |
# +--------------------+--------------------+-------+

# %%
# 6.Salvar a terceira visualização em um tópico no Kafka

#importando bibliotecas streaming e StreamingContext
from pyspark.sql.types import StructType

# %%
dados_visualizacao3 = dados_obitos_confirmados_taxa

# %%
dados_visualizacao3.printSchema()
# Out:
# root
#  |-- Obitos_Confirmados: integer (nullable = true)
#  |-- Obitos_Novos: integer (nullable = true)
#  |-- Taxa_Mortalidade: double (nullable = false)

# %%
dados_visualizacao3_stream = dados_obitos_confirmados_taxa.select(col("Obitos_Confirmados")
                                                        .cast("string"),col("Obitos_Novos")
                                                        .cast("string"),col("Taxa_Mortalidade").cast("string"))

# %%
dados_visualizacao3_stream.printSchema()
# Out:
# root
#  |-- Obitos_Confirmados: string (nullable = true)
#  |-- Obitos_Novos: string (nullable = true)
#  |-- Taxa_Mortalidade: string (nullable = false)

# %%
#dados_visualizacao3_saida = dados_visualizacao3_stream.writeStream\
#    .format("kafka")\
#    .option("kafka.bootstrap.servers", "kafka:9092")\
#    .option("topic","topic-dados-visualizacao")\
#    .option("checkpointLocation", "/user/ronnan/dados_visualizacao11")\
#    .start() """"

# %%
#dados_visualizacao3_output.status

# %%
# 7.Criar a visualização pelo Spark com os dados enviados para o HDFS:
# 8.Salvar a visualização do exercício 6 em um tópico no Elastic
# 9.Criar um dashboard no Elastic para visualização dos novos dados enviados
